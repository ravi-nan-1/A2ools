# %% [markdown]
# # Wan2GP on Google Colab
#
# Sets up [Wan2GP](https://github.com/deepbeepmeep/Wan2GP) in a fresh GPU-backed Colab session.
#
# Run the cells in order to prepare the runtime, install dependencies, and launch the Gradio interface. Click on the link in the output from the last cell to launch the app in your browser.
#
# > **Colab VRAM note:** the free tier usually assigns a 15 GB T4 GPU. Most Wan2GP models exceed that budget; the Wan 2.2 TextImage2Video FastWan model works, producing roughly a 5 second 480p clip in about 8 minutes.

# %% [markdown]
# ## 1. Confirm the accelerator
#
# Choose `Runtime → Change runtime type` and select **GPU** before running anything else.
#
# If this cell raises an error, go back to `Runtime → Change runtime type`, pick **GPU** and save.

# %%
import subprocess

try:
    subprocess.run(['nvidia-smi'], check=True)
except Exception as exc:
    raise RuntimeError(
        'GPU not detected. In Colab, open Runtime → Change runtime type, select GPU (or TPU if GPUs are unavailable), save, then rerun this cell.'
    ) from exc

# %% [markdown]
# ## 2. Configure the workspace path
#
# Choose where Wan2GP should be installed. Update `WAN2GP_ROOT` if you prefer a different location.

# %%
from pathlib import Path

WAN2GP_ROOT = Path('/content/Wan2GP').resolve()
print(f'Wan2GP will be installed to: {WAN2GP_ROOT}')
# Out:
# Wan2GP will be installed to: /content/Wan2GP

# %% [markdown]
# ## 3. Download or update Wan2GP
#
# Clone the repository if it is not present yet; otherwise pull the latest changes.

# %%
import subprocess

repo_url = 'https://github.com/deepbeepmeep/Wan2GP.git'
if WAN2GP_ROOT.exists():
    print('Repository already exists. Pulling latest changes...')
    subprocess.run(['git', '-C', str(WAN2GP_ROOT), 'pull'], check=True)
else:
    subprocess.run(['git', 'clone', repo_url, str(WAN2GP_ROOT)], check=True)

# %% [markdown]
# ## 4. Install system dependencies
#
# Install shared libraries needed for video and audio processing. If you see a warning about skipping an extra repository, it is safe to ignore.

# %%
import os, subprocess

env = os.environ.copy()
env['DEBIAN_FRONTEND'] = 'noninteractive'

subprocess.run(['sudo', 'apt-get', 'update', '-qq'], check=True, env=env)
subprocess.run([
    'sudo', 'apt-get', 'install', '-y', '--no-install-recommends',
    'ffmpeg', 'libglib2.0-0', 'libgl1', 'libportaudio2'
], check=True, env=env)
# Out:
# CompletedProcess(args=['sudo', 'apt-get', 'install', '-y', '--no-install-recommends', 'ffmpeg', 'libglib2.0-0', 'libgl1', 'libportaudio2'], returncode=0)

# %% [markdown]
# ## 5. Install Python dependencies
#
# Install PyTorch, xformers and Wan2GP's Python packages.

# %%
import os, subprocess, sys
from pathlib import Path

WAN2GP_ROOT = Path('/content/Wan2GP')

env = os.environ.copy()
env.setdefault('DEBIAN_FRONTEND', 'noninteractive')

# Install ALL required system dependencies for av
subprocess.run(['apt-get', 'update'], check=True, env=env)
subprocess.run([
    'apt-get', 'install', '-y',
    'ffmpeg',
    'libavformat-dev',
    'libavcodec-dev',
    'libavdevice-dev',
    'libavutil-dev',
    'libswscale-dev',
    'libswresample-dev',
    'libavfilter-dev',
    'pkg-config',
    'libffi-dev',
    'python3-dev'
], check=True, env=env)

# Upgrade pip and build tools
subprocess.run([sys.executable, '-m', 'pip', 'install', '--upgrade', 'pip', 'setuptools', 'wheel', 'cython'], check=True, env=env)

# Try installing a specific older version of av that has better wheel support
subprocess.run([sys.executable, '-m', 'pip', 'install', 'av==12.0.0'], check=True, env=env)

# Install PyTorch and xformers
subprocess.run([sys.executable, '-m', 'pip', 'install', 'torch==2.8.0', 'torchvision', 'torchaudio', '--index-url', 'https://download.pytorch.org/whl/cu128'], check=True, env=env)
subprocess.run([sys.executable, "-m", "pip", "install", "xformers==0.0.32.post2", "--index-url", "https://download.pytorch.org/whl/cu128"], check=True, env=env)

# Install remaining requirements
subprocess.run([sys.executable, '-m', 'pip', 'install', '-r', str(WAN2GP_ROOT / 'requirements.txt')], check=True, env=env)

print("✅ Installation complete!")
# Out:
# ✅ Installation complete!

# %% [markdown]
# ## 5b. Force a headless matplotlib backend
#
# Ensure Wan2GP's preprocessing tools use the headless Agg backend so Step 6 launches cleanly in Colab.

# %%
from pathlib import Path

# Replace the TkAgg backend with the headless Agg backend if present.
target = WAN2GP_ROOT / 'preprocessing/matanyone/tools/interact_tools.py'
needle = "matplotlib.use('TkAgg')"
replacement = "matplotlib.use('Agg')"

if not target.exists():
    print(f'Skipping: {target} not found.')
else:
    text = target.read_text()
    if replacement in text:
        print('Agg backend already set; no change needed.')
    elif needle in text:
        target.write_text(text.replace(needle, replacement, 1))
        print('Replaced TkAgg with Agg in interact_tools.py.')
    else:
        print('Backend call not found; no change made.')
# Out:
# Replaced TkAgg with Agg in interact_tools.py.

# %% [markdown]
# ## 6. Launch Wan2GP
#
# Run the Gradio interface. You will find the gradio link in the output. Click on the link to access the UI. Keep the cell running to stay connected; stop it with the square **Stop** button when you are finished.

# %%
import os, subprocess, sys, threading, time

env = os.environ.copy()
env.setdefault('WAN_CACHE_DIR', str(WAN2GP_ROOT / 'models'))
cmd = [
    sys.executable,
    '-u',
    'wgp.py',
    '--listen',
    '--server-port', '7860',
    '--share',
    '--profile', '5',
]
print('Launching Wan2GP…')
process = subprocess.Popen(
    cmd,
    cwd=str(WAN2GP_ROOT),
    env=env,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)
stop_event = threading.Event()

def keepalive():
    while not stop_event.is_set():
        time.sleep(45)
        if stop_event.is_set():
            break
        print('[keepalive] Notebook cell still running…')

keepalive_thread = threading.Thread(target=keepalive, daemon=True)
keepalive_thread.start()

try:
    for line in iter(process.stdout.readline, ''):
        if not line:
            break
        print(line, end='')
except KeyboardInterrupt:
    print('Stopping Wan2GP…')
    process.terminate()
finally:
    stop_event.set()
    process.wait()
    keepalive_thread.join(timeout=1)
    print(f'Wan2GP stopped (return code: {process.returncode}).')
# Out:
# Launching Wan2GP…
# 2026-01-11 09:08:01.229770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768122481.530147    3830 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768122481.609204    3830 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768122482.214418    3830 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768122482.214469    3830 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768122482.214473    3830 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768122482.214476    3830 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-11 09:08:02.271213: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# /content/Wan2GP/models/ltx_video/schedulers/rf.py:323: SyntaxWarning: invalid escape sequence '\D'
#   z_{t_1} = z_t - \Delta_t * v
# Switching to FP16 models when possible as GPU architecture doesn't support optimed BF16 Kernels
# [Plugins] Auto-installing default plugin: wan2gp-gallery...
# Ignoring comtypes: markers 'sys_platform == "win32"' don't match your environment
# [Plugins] Install result for wan2gp-gallery: [Success] Plugin 'wan2gp-gallery' installed. Please enable it in the list and restart WanGP.
# [Plugins] Auto-installing default plugin: wan2gp-lora-multipliers-ui...
# [Plugins] Install result for wan2gp-lora-multipliers-ui: [Success] Plugin 'wan2gp-lora-multipliers-ui' installed. Please enable it in the list and restart WanGP.
# [Plugins] Disabling newly installed default plugins...
# Switching to FP16 models when possible as GPU architecture doesn't support optimed BF16 Kernels
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://4d476d83b8112ada02.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# Loading Model 'ckpts/wan2.2_text2video_5B_quanto_mbf16_int8.safetensors' ...
# ************ Memory Management for the GPU Poor (mmgp 3.6.11) by DeepBeepMeep ************
# [keepalive] Notebook cell still running…
# Hooked to model 'transformer' (WanModel)
# Async loading plan for model 'transformer' : base size of 4.52 MB will be preloaded with a 156.23 MB async circular shuttle
# Hooked to model 'text_encoder' (T5Encoder)
# Async loading plan for model 'text_encoder' : base size of 2003.01 MB will be preloaded with a 184.10 MB async circular shuttle
# Hooked to model 'vae' (WanVAE_)
# Lora 'loras/wan_5B/Wan2_2_5B_FastWanFullAttn_lora_rank_128_bf16.safetensors' was loaded in model 'models.wan.modules.model'
# [keepalive] Notebook cell still running…
#
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#   0%|          | 0/3 [00:00<?, ?steps/s]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#  33%|███▎      | 1/3 [02:03<04:06, 123.20s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#  67%|██████▋   | 2/3 [04:03<02:01, 121.62s/steps]
# 100%|██████████| 3/3 [06:04<00:00, 121.42s/steps]
# 100%|██████████| 3/3 [06:04<00:00, 121.63s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-01-11-09h29m44s_seed907223960_make this image live make her talking and she take the cup and start drink.mp4
# [keepalive] Notebook cell still running…
#
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#   0%|          | 0/3 [00:00<?, ?steps/s]
# [keepalive] Notebook cell still running…
#  33%|███▎      | 1/3 [01:15<02:31, 75.58s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#  67%|██████▋   | 2/3 [02:28<01:13, 73.93s/steps]
# 100%|██████████| 3/3 [03:41<00:00, 73.60s/steps]
# 100%|██████████| 3/3 [03:41<00:00, 73.85s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-01-11-09h36m45s_seed907223960_make this image live make her talking and she take the cup and start drink.mp4
# Audio notification fallback: /proc/asound/cards is missing (no ALSA devices); using terminal beep.
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# Loading Model 'ckpts/ltx-2-19b-distilled-fp8.safetensors' ...
# [keepalive] Notebook cell still running…
# Hooked to model 'transformer' (X0Model)
# Async loading plan for model 'transformer' : base size of 443.16 MB will be preloaded with a 736.38 MB async circular shuttle
# Hooked to model 'text_encoder' (Gemma3ForConditionalGeneration)
# Async loading plan for model 'text_encoder' : base size of 1939.25 MB will be preloaded with a 213.87 MB async shuttle
# Hooked to model 'text_embedding_projection' (GemmaFeaturesExtractorProjLinear)
# Hooked to model 'text_embeddings_connector' (GemmaTextEmbeddingsConnectorModel)
# Hooked to model 'vae' (VideoDecoder)
# Async loading plan for model 'vae' : base size of 7.07 MB will be preloaded with a 574.07 MB async circular shuttle
# Hooked to model 'video_encoder' (VideoEncoder)
# Async loading plan for model 'video_encoder' : base size of 13.92 MB will be preloaded with a 864.02 MB async circular shuttle
# Hooked to model 'audio_encoder' (AudioEncoder)
# Hooked to model 'audio_decoder' (AudioDecoder)
# Hooked to model 'vocoder' (Vocoder)
# Hooked to model 'spatial_upsampler' (LatentUpsampler)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/utils.py:213: UserWarning: In 2.9, this function's implementation will be changed to use torchaudio.load_with_torchcodec` under the hood. Some parameters like ``normalize``, ``format``, ``buffer_size``, and ``backend`` will be ignored. We recommend that you port your code to rely directly on TorchCodec's decoder instead: https://docs.pytorch.org/torchcodec/stable/generated/torchcodec.decoders.AudioDecoder.html#torchcodec.decoders.AudioDecoder.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchaudio/_backend/ffmpeg.py:88: UserWarning: torio.io._streaming_media_decoder.StreamingMediaDecoder has been deprecated. This deprecation is part of a large refactoring effort to transition TorchAudio into a maintenance phase. The decoding and encoding capabilities of PyTorch for both audio and video are being consolidated into TorchCodec. Please see https://github.com/pytorch/audio/issues/3902 for more information. It will be removed from the 2.9 release.
#   s = torchaudio.io.StreamReader(src, format, None, buffer_size)
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#   0%|          | 0/8 [00:00<?, ?steps/s]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#  12%|█▎        | 1/8 [06:02<42:15, 362.28s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#  25%|██▌       | 2/8 [12:14<36:48, 368.09s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#  38%|███▊      | 3/8 [18:23<30:43, 368.62s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
